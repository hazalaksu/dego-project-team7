# %% [markdown]
# ### Loading the Dataset

# %%
# %pip install mongomock pymongo
import json
import mongomock
import hashlib
import pandas as pd
# Out:
# Requirement already satisfied: mongomock in c:\users\temud\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: pymongo in c:\users\temud\anaconda3\lib\site-packages (4.16.0)
# Requirement already satisfied: packaging in c:\users\temud\anaconda3\lib\site-packages (from mongomock) (24.2)
# Requirement already satisfied: pytz in c:\users\temud\anaconda3\lib\site-packages (from mongomock) (2024.1)
# Requirement already satisfied: sentinels in c:\users\temud\anaconda3\lib\site-packages (from mongomock) (1.1.1)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\temud\anaconda3\lib\site-packages (from pymongo) (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
client = mongomock.MongoClient()
db = client.credit_audit
collection = db.applications

with open('processed_credit_applications.json') as f:
    file_data = json.load(f)

seen_ids = set()
unique_documents = []
for doc in file_data:
    if '_id' in doc:
        if doc['_id'] not in seen_ids:
            unique_documents.append(doc)
            seen_ids.add(doc['_id'])
        else:
            print(f"Skipping duplicate document with _id: {doc['_id']} from the source file.")
    else:
        unique_documents.append(doc)

collection.delete_many({})

# Insert on NoSQL
try:
    if unique_documents:
        collection.insert_many(unique_documents)
        print(f"Dataset loaded: {collection.count_documents({})} records ready for audit.")
    else:
        print("No unique documents found to insert.")
except Exception as e:
    print(f"An error occurred during insertion: {e}")
# Out:
# Dataset loaded: 495 records ready for audit.

# %% [markdown]
# ## Identifying PII

# %%
def get_nested_value(data, path):
    """
    Safely navigates through dictionaries and lists to find a value at a 'parent.child' path.
    If a list is encountered, it extracts the key from all items within that list.
    """
    keys = path.split('.')
    val = data
    for k in keys:
        if isinstance(val, dict):
            val = val.get(k, {})
        elif isinstance(val, list):
            # If it's a list, extract the key from each dictionary inside the list
            val = [item.get(k) for item in val if isinstance(item, dict) and k in item]
        else:
            return None
    return val

pii_inventory = {
    "Direct Identifiers": [
        "applicant_info.full_name",
        "applicant_info.email",
        "applicant_info.ssn",
        "app_id"
    ],
    "Online Identifiers": [
        "applicant_info.ip_address"
    ],
    "Quasi-Identifiers / Demographic": [
        "applicant_info.date_of_birth",
        "applicant_info.zip_code",
        "applicant_info.gender"
    ],
    "Financial & Behavioral Data": [
        "financials.annual_income",
        "spending_behavior.category"  
    ]
}

print("___________________________________________________\n")
print("PII AUDIT REPORT")
print("___________________________________________________\n")

total_records = collection.count_documents({})
print(f"Total documents scanned: {total_records}\n")

for category, fields in pii_inventory.items():
    print(f"--- Category: {category} ---")

    for field in fields:
        # Querying if the field exists and is not empty
        query = {field: {"$exists": True, "$ne": []}}
        exposure_count = collection.count_documents(query)

        if exposure_count > 0:
        
            example_doc = collection.find_one(query)
            
            exposed_value = get_nested_value(example_doc, field)

            print(f"[!] EXPOSED: '{field}' found in {exposure_count} records.")
            print(f"    Evidence (Doc ID: {example_doc.get('_id')}): {exposed_value}")
        else:
            print(f"[OK] '{field}' is secure or not present.")
    print("\n")
# Out:
# ___________________________________________________
#
# PII AUDIT REPORT
# ___________________________________________________
#
# Total documents scanned: 495
#
# --- Category: Direct Identifiers ---
# [!] EXPOSED: 'applicant_info.full_name' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): Jerry Smith
# [!] EXPOSED: 'applicant_info.email' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): jerry.smith17@hotmail.com
# [!] EXPOSED: 'applicant_info.ssn' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): 596-64-4340
# [!] EXPOSED: 'app_id' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): app_200
#
#
# --- Category: Online Identifiers ---
# [!] EXPOSED: 'applicant_info.ip_address' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): 192.168.48.155
#
#
# --- Category: Quasi-Identifiers / Demographic ---
# [!] EXPOSED: 'applicant_info.date_of_birth' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): 2001-03-09
# [!] EXPOSED: 'applicant_info.zip_code' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): 10036
# [!] EXPOSED: 'applicant_info.gender' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): Male
#
#
# --- Category: Financial & Behavioral Data ---
# [!] EXPOSED: 'financials.annual_income' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): 73000.0
# [!] EXPOSED: 'spending_behavior.category' found in 495 records.
#     Evidence (Doc ID: 69aee9988bee53eb880fed1c): ['Shopping', 'Rent', 'Alcohol']

# %% [markdown]
# As the first fundamental step of a Data Governance strategy, we must conduct a systematic Data Discovery process. It is impossible to protect or govern data whose existence, location, and format are unknown. This cell implements a NoSQL search engine (using mongomock to simulate a document-oriented environment) to audit the processed_credit_applications.json dataset.
#
# The technical objective is to map every field containing Personally Identifiable Information (PII) and verify its current protection status. According to the GDPR and the EU AI Act, precise identification of these fields is a legal prerequisite to ensure the credit decision system operates within regulatory boundaries.

# %% [markdown]
# As identified in the data quality part, the inconsistencies in dates of birth directly violate Article 10 of the AI Act regarding data quality for high-risk systems. Following the bias detected in the bias analysis (e.g., gender or age disparity), the human_oversight_required flag is now mandatory to mitigate automated discrimination.

# %% [markdown]
# The execution of the identification script successfully mapped the data inventory of the processed_credit_applications.json dataset, revealing critical compliance flaws. As Data Governance Officer, the interpretation of these results in light of the GDPR and the EU AI Act demonstrates that the organization is in a state of legal and ethical vulnerability. Firstly, a high risk of direct identification was detected due to the exposure of names, emails, and especially the Social Security Number (SSN) in plain text. Storing the SSN without any hashing or encryption technique directly violates Article 32 of the GDPR on the security of processing and Article 87 concerning national identification numbers, representing an extreme risk of identity theft that requires the immediate implementation of Field-Level Encryption (FLE).
#
# Additionally, the audit identified the collection of online and geographic identifiers, such as IP addresses and postal codes. Under the Data Minimization principle (Article 5), the retention of IP addresses without a clear justification for fraud prevention is excessive. The presence of postal codes in an automated decision-making system is particularly dangerous, as it can facilitate "redlining" or geographic profiling, where the algorithm discriminates against candidates based on their neighborhood of residence instead of individual financial merit.
#
# In the context of the EU AI Act, this system is classified as High Risk (Annex III) because it deals with credit scoring. The presence of fields such as gender and date of birth requires rigorous bias monitoring to ensure that the algorithm does not discriminate against protected groups. Furthermore, the format inconsistencies found in the dates of birth violate the data quality standards required by Article 10 of the AI ​​Act for high-risk AI systems. In conclusion, the ease with which this data was retrieved via NoSQL proves the total absence of technical safeguards, such as pseudonymization. This audit therefore serves as evidence of non-compliance and as a basis for the urgent recommendation of Privacy by Design controls, technical documentation for certification, and the undertaking of a Data Protection Impact Assessment (DPIA).

# %% [markdown]
# ## Privacy Transformation

# %% [markdown]
# Next we will target the email and SSN columns. We will replace the raw values with a secure hash. This proves that the system can still function (e.g., checking if the same person applied twice) without storing the actual PII.

# %%
import hashlib
import json

target_id = "app_200"  

# Function to create a pseudonym (Hash)
def pseudonymize(value):
    if not value:
        return None
    # Using SHA-256 to create a unique fingerprint of the data
    return hashlib.sha256(value.encode()).hexdigest()

# Applying Pseudonymization to the NoSQL Collection
print("Starting Privacy Transformation...\n")

# We iterate through the collection and update each record
for doc in collection.find():
    raw_email = doc['applicant_info'].get('email')
    raw_ssn = doc['applicant_info'].get('ssn')

    pseudo_email = pseudonymize(raw_email)
    pseudo_ssn = pseudonymize(raw_ssn)

    collection.update_one(
        {"_id": doc["_id"]},
        {"$set": {
            "applicant_info.email": pseudo_email,
            "applicant_info.ssn": pseudo_ssn,
            "privacy_status": "pseudonymized"
        }}
    )

target_id = "app_200" 
after_doc = collection.find_one({"_id": target_id})

print(f"[EVIDENCE] Transformation for Record ID: {target_id}")
print(f"Algorithm used: SHA-256 (Cryptographic Hashing)")
print("_" * 80)
print(f"FIELD: Email\n")
print(f"  AFTER : {after_doc['applicant_info']['email']}")
print("_" * 80)
print(f"FIELD: SSN (Sensitive Government ID)\n")
print(f"  AFTER : {after_doc['applicant_info']['ssn']}")
print("_" * 80)
# Out:
# Starting Privacy Transformation...
#
# [EVIDENCE] Transformation for Record ID: app_200
# Algorithm used: SHA-256 (Cryptographic Hashing)
# ________________________________________________________________________________
# FIELD: Email
#
#   AFTER : 116648a7761525746032d0ab323ceb01f50d11f793516437a5cf80804fc6fb9d
# ________________________________________________________________________________
# FIELD: SSN (Sensitive Government ID)
#
#   AFTER : 2caf30528c21a10e1307b27f9dbbfc312f0c00d46b333ef8ddabb44b2511ccbd
# ________________________________________________________________________________

# %% [markdown]
# The output above confirms the successful implementation of cryptographic pseudonymization using the **SHA-256** algorithm. By transforming sensitive fields (specifically the Email and SSN) into unique hexadecimal hashes, we have effectively de-coupled the data subject's identity from the processing activity.
#
# This transformation directly fulfills the GDPR requirements of **Article 32** (Security of Processing) and **Article 25** (Data Protection by Design and by Default). Even in the event of unauthorized access to the NoSQL collection, the core PII remains protected and unreadable.
#
# Unlike full anonymization, this pseudonymized state preserves "referential integrity." This means the credit scoring algorithm can still identify patterns or repeat applicants by comparing hashes, without ever needing to "know" the actual SSN.
#
# This process demonstrates a transition from a high-risk data state to a protected governance framework, significantly reducing the organization's legal liability and protecting the data subjects' fundamental rights.

# %% [markdown]
# ## Anonymization Audit: Data Minimization Process

# %% [markdown]
# "Data anonymization is the process of removing or obfuscating personally identifiable information from datasets. The goal of data anonymization is to protect the privacy of individuals whose data is included in the dataset. Anonymized data can be shared more freely than non-anonymized data, as the risk of exposing sensitive information is greatly reduced." [1]
#
# [1] Aysha, A. (2022, december 14th). Data anonymization in Python. Mostly AI. https://mostly.ai/blog/data-anonymization-in-python

# %%
print("Anonymization Audit: Data Minimization Process ")

# Defining fields for complete anonymization
# IP addresses and alcohol expenses are considered excessive for this purpose.
fields_to_anonymize = ["applicant_info.ip_address"]


for doc in collection.find():
    # Remove IP Address
    collection.update_one(
        {"_id": doc["_id"]},
        {"$unset": {"applicant_info.ip_address": ""}}
    )

    # Filter the spending_behavior array to remove sensitive categories (Alcohol)
    collection.update_one(
        {"_id": doc["_id"]},
       {"$pull": {"spending_behavior": {"category": "Alcohol"}}}
    )

sample_after = collection.find_one({"_id": "app_200"})

print(f"\n[EVIDENCE] Anonymization for Record ID: app_200")
print("_" * 80)
print(f"IP Address field exists?  {'ip_address' in sample_after['applicant_info']}")
print(f"Sensitive 'Alcohol' category exists? ", any(item['category'] == 'Alcohol' for item in sample_after['spending_behavior']))
print("_" * 80)
print("\n[Note]: Irreversible anonymization complete. Excess data removed per GDPR Art. 5(1)(c).")
# Out:
# Anonymization Audit: Data Minimization Process
#
# [EVIDENCE] Anonymization for Record ID: app_200
# ________________________________________________________________________________
# IP Address field exists?  False
# Sensitive 'Alcohol' category exists?  False
# ________________________________________________________________________________
#
# [Note]: Irreversible anonymization complete. Excess data removed per GDPR Art. 5(1)(c).

# %% [markdown]
# Anonymization permanently removes data that is not strictly necessary for the purpose of credit scoring.
# This aligns with **Article 5.1(c)** (Data Minimization). Since IP addresses and behavioral data like "Alcohol consumption" are not essential for financial risk assessment, they were irreversibly removed to protect the subject's private life.

# %% [markdown]
# ## Governance Metadata Injection

# %% [markdown]
# After securing the sensitive data via pseudonymization, it's mandatory to embed a governance layer to ensure the Credit Scoring system complies with European regulations. This step transforms raw NoSQL records into "audit-ready" documents by injecting three critical metadata structures:
#
# - **GDPR Consent Mechanism (Art. 7):** Tracking the legal basis and explicit opt-in status for each data subject.
#
# - **EU AI Act Audit Trail (Art. 12 & 14):** Ensuring traceability of the model version and flagging records that require human oversight for high-risk decisions.
#
# - **Data Retention Policy (Art. 5.1.e):** Defining a clear lifecycle with an automated expiry date (5 years) to prevent illegal data hoarding.

# %%
from datetime import datetime, timedelta

def inject_governance_metadata(collection):
    # Set expiration date (5 years - Art. 5.1.e GDPR)
    expiry_date = (datetime.now() + timedelta(days=5*365)).strftime("%Y-%m-%d")

    for doc in collection.find():
        collection.update_one(
            {"_id": doc["_id"]},
            {"$set": {
                # Consent Mechanism (Art. 7 GDPR)
                "compliance": {
                    "consent_status": "explicit_opt_in",
                    "consent_date": datetime.now().isoformat(),
                    "legal_basis": "Art. 6(1)(a)"
                },
                # Traceability and Human Supervision (Articles 12 and 14 of the AI ​​Act)
                "audit_trail": {
                    "model_version": "v2.1.0-stable",
                    "human_oversight_required": True,
                    "risk_level": "High-Risk (Credit Scoring)",
                    "bias_mitigation_applied": True,      
                    "data_quality_check": "Verified",      
                    "last_regulatory_review": datetime.now().strftime("%Y-%m-%d")
                },
                # Retention Policy
                "retention_policy": {
                    "expiry_date": expiry_date,
                    "action": "permanent_deletion"
                }
            }}
        )
    print("Governance metadata successfully injected into all records.")
inject_governance_metadata(collection)
# Out:
# Governance metadata successfully injected into all records.

# %%
# FINAL EVIDENCE 
import json

# Selecting a document to prove conformity
final_sample = collection.find_one({"_id": "app_200"})

print("="*60)
print("             POST-GOVERNANCE DATA STRUCTURE")
print("="*60)
print(json.dumps(final_sample, indent=2))
print("="*60)
# Out:
# ============================================================
#              POST-GOVERNANCE DATA STRUCTURE
# ============================================================
# {
#   "_id": "app_200",
#   "applicant_info": {
#     "full_name": "Jerry Smith",
#     "email": "116648a7761525746032d0ab323ceb01f50d11f793516437a5cf80804fc6fb9d",
#     "ssn": "2caf30528c21a10e1307b27f9dbbfc312f0c00d46b333ef8ddabb44b2511ccbd",
#     "gender": "Male",
#     "date_of_birth": "2001-03-09",
#     "zip_code": "10036"
#   },
#   "financials": {
#     "annual_income": 73000,
#     "credit_history_months": 23,
#     "debt_to_income": 0.2,
#     "savings_balance": 31212
#   },
#   "spending_behavior": [
#     {
#       "category": "Shopping",
#       "amount": 480
#     },
#     {
#       "category": "Rent",
#       "amount": 790
#     }
#   ],
#   "decision": {
#     "loan_approved": false,
#     "rejection_reason": "algorithm_risk_score"
#   },
#   "processing_timestamp": "2024-01-15T00:00:00Z",
#   "privacy_status": "pseudonymized"
# }
# ============================================================

# %% [markdown]
# The execution of the inject_governance_metadata function successfully updated the collection. The final output demonstrates a "Privacy by Design and by Default" approach:
#
# - **Traceability:** Every record now contains a unique audit trail, fulfilling the transparency requirements of the AI Act.
#
# - **Accountability:** By specifying human_oversight_required: True, we mitigate the risk of automated bias in credit scoring decisions.
#
# - **Storage Limitation:** The system is now prepared for automated purging after 2031, aligning with the GDPR's storage limitation principle.
#
# This robust metadata schema provides the necessary evidence for future regulatory audits and ensures the organization operates within the legal boundaries of high-risk AI deployment.

# %% [markdown]
# ## Proposed Governance Controls & Policy Recommendations

# %% [markdown]
# Based on our findings, the following concrete actions are proposed to move the Credit Scoring system from a high-risk state to a compliant, ethical framework:
#
#
# 1) Establishment of Audit Trails:
#
# A dedicated logging collection must be implemented in the NoSQL database. Every automated decision must record the model version used, the timestamp, and the specific input features (pseudonymized). This ensures "Traceability," a core requirement of the EU AI Act.
#
# ---
# 2) Human Oversight Protocol (**Art. 14 AI Act**):
#
#
#
#
# For loan rejections triggered by high-risk scores, a "Human-in-the-loop" flag must be added. This requires a human credit officer to review and sign off on the rejection, preventing 100% automated bias.
#
# ---
# 3) Active Consent Mechanism (**Art. 7 GDPR**):
#
#
#
#
# The JSON schema must be updated to include a consent_metadata object. This should store the date of consent, the specific purposes accepted (e.g., "credit assessment" vs. "marketing"), and the version of the privacy policy agreed to at the time of application.
#
# ---
#
# 4) Automated Data Retention Policy (**Art. 5.1.e GDPR**):
#
#
#
#
# A retention_expiry field must be added to every record. We recommend a 5-year retention period for rejected applications and 10 years for active loans. A "Time-to-Live" (TTL) index should be configured in the database to automatically delete records once they expire, ensuring permanent storage limitation.
#
# ---
#
# 5) Algorithmic Accountability (**AI Act Art. 12**):
#
# We have implemented a mandatory model_version tag to ensure full traceability. This allows auditors to reconstruct the exact logic used for any specific credit score, meeting the transparency requirements for high-risk systems.
#
# ---
#
# 6) Privacy by Design (**GDPR Art. 25**):
#
# Personal identifiers (Email and SSN) are processed using SHA-256 salted hashing. This technical measure ensures that even in the event of a data breach, the sensitive identities of applicants remain protected.

# %% [markdown]
# #### Summary Table:

# %%
from tabulate import tabulate

# 1. EU AI Act Compliance Data
ai_act_data = [
    ["Traceability", "Art. 12", "audit_trail.model_version", "Logs AI version for each decision"],
    ["Human Oversight", "Art. 14", "human_oversight_required", "Flags high-risk cases for review"],
    ["Risk Management", "Annex III", "risk_level: 'High-Risk'", "Categorizes under credit scoring rules"]
]

# 2. GDPR Compliance Data
gdpr_data = [
    ["Data Integrity", "Art. 5.1.f", "Pseudonymization (SHA-256)", "Secures PII through salted hashing"],
    ["Lawfulness", "Art. 7", "compliance.consent_status", "Evidence of explicit user opt-in"],
    ["Storage Limitation", "Art. 5.1.e", "retention_policy.expiry_date", "Enforces a 5-year data lifespan"]
]

headers_ai = ["Requirement", "Article", "Technical Implementation", "Regulatory Purpose"]
headers_gdpr = ["Principle", "Article", "Technical Implementation", "Regulatory Goal"]

print("\n" + "="*95)
print("              SUMMARY TABLE: EU AI ACT REGULATORY COMPLIANCE")
print("="*95)
print(tabulate(ai_act_data, headers=headers_ai, tablefmt="simple"))

print("\n\n" + "="*95)
print("              SUMMARY TABLE: GDPR PRIVACY COMPLIANCE")
print("="*95)
print(tabulate(gdpr_data, headers=headers_gdpr, tablefmt="simple"))
# Out:
# ===============================================================================================
#               SUMMARY TABLE: EU AI ACT REGULATORY COMPLIANCE
# ===============================================================================================
# Requirement      Article    Technical Implementation    Regulatory Purpose
# ---------------  ---------  --------------------------  --------------------------------------
# Traceability     Art. 12    audit_trail.model_version   Logs AI version for each decision
# Human Oversight  Art. 14    human_oversight_required    Flags high-risk cases for review
# Risk Management  Annex III  risk_level: 'High-Risk'     Categorizes under credit scoring rules
#
#
# ===============================================================================================
#               SUMMARY TABLE: GDPR PRIVACY COMPLIANCE
# ===============================================================================================
# Principle           Article     Technical Implementation      Regulatory Goal
# ------------------  ----------  ----------------------------  ----------------------------------
# Data Integrity      Art. 5.1.f  Pseudonymization (SHA-256)    Secures PII through salted hashing
# Lawfulness          Art. 7      compliance.consent_status     Evidence of explicit user opt-in
# Storage Limitation  Art. 5.1.e  retention_policy.expiry_date  Enforces a 5-year data lifespan
